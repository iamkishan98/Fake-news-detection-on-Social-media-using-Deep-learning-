# %% [markdown]
# <a href="https://colab.research.google.com/github/iamkishan98/Fake-news-detection-on-Social-media-using-Deep-learning-/blob/main/facebook_fact_check.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/My Drive/Fakenews/')

# %%
import pandas as pd

# %%
percentify = lambda x: (x * 100).round(1).astype(str) + "%"

# %%
posts = pd.read_csv("facebook-fact-check.csv")

# %%
len(posts)
# Out:
# 2282

# %%
ENGAGEMENT_COLS = [
    "share_count",
    "reaction_count",
    "comment_count"
]

# %%
RATINGS = ["mostly false", "mixture of true and false", "mostly true", "no factual content"]
FACTUAL_RATINGS = ["mostly false", "mixture of true and false", "mostly true"]

# %%
category_grp = posts.groupby("Category")
page_grp = posts.groupby([ "Category", "Page" ])
type_grp = posts.groupby([ "Category", "Page", "Post Type" ])

# %% [markdown]
# ## Rating by category

# %% [markdown]
# Counts:

# %%
rating_by_category = category_grp["Rating"].value_counts().unstack()[RATINGS].fillna(0)
rating_by_category["total"] = rating_by_category.sum(axis=1)
rating_by_category
# Out:
# Rating      mostly false  mixture of true and false  ...  no factual content   total
# Category                                             ...
# left                22.0                       68.0  ...               116.0   471.0
# mainstream           0.0                        8.0  ...                52.0  1145.0
# right               82.0                      169.0  ...                96.0   666.0
#
# [3 rows x 5 columns]

# %% [markdown]
# Percentages, of all posts:

# %%
(rating_by_category[RATINGS].T / rating_by_category[RATINGS].sum(axis=1)).T\
    .pipe(percentify)
# Out:
# Rating     mostly false  ... no factual content
# Category                 ...
# left               4.7%  ...              24.6%
# mainstream         0.0%  ...               4.5%
# right             12.3%  ...              14.4%
#
# [3 rows x 4 columns]

# %% [markdown]
# Percentages, of posts not rated "no factual content":

# %%
(rating_by_category[FACTUAL_RATINGS].T / rating_by_category[FACTUAL_RATINGS].sum(axis=1)).T\
    .pipe(percentify)
# Out:
# Rating     mostly false mixture of true and false mostly true
# Category
# left               6.2%                     19.2%       74.6%
# mainstream         0.0%                      0.7%       99.3%
# right             14.4%                     29.6%       56.0%

# %% [markdown]
# ## Rating by page

# %% [markdown]
# Counts:

# %%
rating_by_page = page_grp["Rating"].value_counts().unstack()[RATINGS].fillna(0)
rating_by_page["total"] = rating_by_page.sum(axis=1)
rating_by_page
# Out:
# Rating                        mostly false  ...  total
# Category   Page                             ...
# left       Addicting Info              8.0  ...  140.0
#            Occupy Democrats            9.0  ...  209.0
#            The Other 98%               5.0  ...  122.0
# mainstream ABC News Politics           0.0  ...  200.0
#            CNN Politics                0.0  ...  409.0
#            Politico                    0.0  ...  536.0
# right      Eagle Rising               30.0  ...  286.0
#            Freedom Daily              26.0  ...  112.0
#            Right Wing News            26.0  ...  268.0
#
# [9 rows x 5 columns]

# %% [markdown]
# Percentages, of all posts:

# %%
(rating_by_page[RATINGS].T / rating_by_page[RATINGS].sum(axis=1)).T\
    .pipe(percentify)
# Out:
# Rating                       mostly false  ... no factual content
# Category   Page                            ...
# left       Addicting Info            5.7%  ...               7.9%
#            Occupy Democrats          4.3%  ...              31.1%
#            The Other 98%             4.1%  ...              32.8%
# mainstream ABC News Politics         0.0%  ...              13.0%
#            CNN Politics              0.0%  ...               4.9%
#            Politico                  0.0%  ...               1.1%
# right      Eagle Rising             10.5%  ...              28.3%
#            Freedom Daily            23.2%  ...               3.6%
#            Right Wing News           9.7%  ...               4.1%
#
# [9 rows x 4 columns]

# %% [markdown]
# Percentages, of posts not rated "no factual content":

# %%
(rating_by_page[FACTUAL_RATINGS].T / rating_by_page[FACTUAL_RATINGS].sum(axis=1)).T\
    .pipe(percentify)
# Out:
# Rating                       mostly false mixture of true and false mostly true
# Category   Page
# left       Addicting Info            6.2%                     19.4%       74.4%
#            Occupy Democrats          6.2%                     22.9%       70.8%
#            The Other 98%             6.1%                     12.2%       81.7%
# mainstream ABC News Politics         0.0%                      1.1%       98.9%
#            CNN Politics              0.0%                      1.0%       99.0%
#            Politico                  0.0%                      0.4%       99.6%
# right      Eagle Rising             14.6%                     26.3%       59.0%
#            Freedom Daily            24.1%                     24.1%       51.9%
#            Right Wing News          10.1%                     34.6%       55.3%

# %% [markdown]
# ## Number of posts by date

# %% [markdown]
# Counts:

# %%
posts_by_date_by_category = category_grp["Date Published"].value_counts().unstack()
posts_by_date_by_category["Avg. Per Day"] = posts_by_date_by_category.mean(axis=1).round(0)
posts_by_date_by_category
# Out:
# Date Published  19-09-2016  20-09-2016  ...  27-09-2016  Avg. Per Day
# Category                                ...
# left                    55          70  ...          88          67.0
# mainstream             154         156  ...         180         164.0
# right                   97          91  ...          95          95.0
#
# [3 rows x 8 columns]

# %%
posts_by_date_by_page = page_grp["Date Published"].value_counts().unstack()
posts_by_date_by_page["Avg. Per Day"] = posts_by_date_by_page.mean(axis=1).round(0)
posts_by_date_by_page
# Out:
# Date Published                19-09-2016  20-09-2016  ...  27-09-2016  Avg. Per Day
# Category   Page                                       ...
# left       Addicting Info             22          18  ...          23          20.0
#            Occupy Democrats           20          30  ...          44          30.0
#            The Other 98%              13          22  ...          21          17.0
# mainstream ABC News Politics          36          22  ...          29          29.0
#            CNN Politics               54          61  ...          65          58.0
#            Politico                   64          73  ...          86          77.0
# right      Eagle Rising               41          41  ...          39          41.0
#            Freedom Daily              19          16  ...          15          16.0
#            Right Wing News            37          34  ...          41          38.0
#
# [9 rows x 8 columns]

# %% [markdown]
# ## Rating by post type

# %%
rating_by_post_type = type_grp["Rating"].value_counts().unstack()[RATINGS].fillna(0)
rating_by_post_type["total"] = rating_by_post_type.sum(axis=1)
rating_by_post_type
# Out:
# Rating                                  mostly false  ...  total
# Category   Page              Post Type                ...
# left       Addicting Info    link                8.0  ...  134.0
#                              photo               0.0  ...    4.0
#                              video               0.0  ...    2.0
#            Occupy Democrats  link                7.0  ...   94.0
#                              photo               2.0  ...   78.0
#                              video               0.0  ...   37.0
#            The Other 98%     link                1.0  ...   51.0
#                              photo               4.0  ...   41.0
#                              video               0.0  ...   30.0
# mainstream ABC News Politics link                0.0  ...  108.0
#                              photo               0.0  ...   13.0
#                              text                0.0  ...    1.0
#                              video               0.0  ...   78.0
#            CNN Politics      link                0.0  ...  330.0
#                              photo               0.0  ...    8.0
#                              text                0.0  ...    1.0
#                              video               0.0  ...   70.0
#            Politico          link                0.0  ...  463.0
#                              photo               0.0  ...    7.0
#                              text                0.0  ...    1.0
#                              video               0.0  ...   65.0
# right      Eagle Rising      link               27.0  ...  231.0
#                              photo               3.0  ...   46.0
#                              video               0.0  ...    9.0
#            Freedom Daily     link               26.0  ...  111.0
#                              text                0.0  ...    1.0
#            Right Wing News   link               26.0  ...  258.0
#                              photo               0.0  ...   10.0
#
# [28 rows x 5 columns]

# %% [markdown]
# # Engagement

# %% [markdown]
# Count of missing engagement figures:

# %%
posts[ENGAGEMENT_COLS].isnull().sum()
# Out:
# share_count       70
# reaction_count     2
# comment_count      2
# dtype: int64

# %% [markdown]
# ## Median engagement by page

# %%
page_grp[ENGAGEMENT_COLS].median().round()
# Out:
#                               share_count  reaction_count  comment_count
# Category   Page
# left       Addicting Info           563.0          2230.0          271.0
#            Occupy Democrats       10931.0         22360.0         1205.0
#            The Other 98%           3942.0         12083.0          521.0
# mainstream ABC News Politics         13.0            80.0           28.0
#            CNN Politics              50.0           340.0          194.0
#            Politico                  33.0           314.0           95.0
# right      Eagle Rising              92.0           186.0           22.0
#            Freedom Daily            947.0          2245.0          214.0
#            Right Wing News          266.0           913.0           91.0

# %% [markdown]
# ## Average engagement by page

# %%
page_grp[ENGAGEMENT_COLS].mean().round()
# Out:
#                               share_count  reaction_count  comment_count
# Category   Page
# left       Addicting Info          1270.0          3120.0          392.0
#            Occupy Democrats       29205.0         34669.0         2858.0
#            The Other 98%          18007.0         20971.0          915.0
# mainstream ABC News Politics         44.0           177.0           71.0
#            CNN Politics             183.0           678.0          322.0
#            Politico                 182.0           900.0          170.0
# right      Eagle Rising             616.0           520.0           79.0
#            Freedom Daily           2474.0          3685.0          516.0
#            Right Wing News         1398.0          2454.0          360.0

# %% [markdown]
# ## Engagement by truthfulness

# %%
grp = posts.groupby([ "Category", "Page", "Rating" ])

# %% [markdown]
# Counts:

# %%
grp[ENGAGEMENT_COLS].size().unstack().fillna(0)
# Out:
# Rating                        mixture of true and false  ...  no factual content
# Category   Page                                          ...
# left       Addicting Info                          25.0  ...                11.0
#            Occupy Democrats                        33.0  ...                65.0
#            The Other 98%                           10.0  ...                40.0
# mainstream ABC News Politics                        2.0  ...                26.0
#            CNN Politics                             4.0  ...                20.0
#            Politico                                 2.0  ...                 6.0
# right      Eagle Rising                            54.0  ...                81.0
#            Freedom Daily                           26.0  ...                 4.0
#            Right Wing News                         89.0  ...                11.0
#
# [9 rows x 4 columns]

# %% [markdown]
# Medians:

# %%
grp[ENGAGEMENT_COLS].median().round()
# Out:
#                                                         share_count  ...  comment_count
# Category   Page              Rating                                  ...
# left       Addicting Info    mixture of true and false       1132.0  ...          402.0
#                              mostly false                     285.0  ...          394.0
#                              mostly true                      523.0  ...          235.0
#                              no factual content               399.0  ...          153.0
#            Occupy Democrats  mixture of true and false      10654.0  ...         1461.0
#                              mostly false                    5541.0  ...          638.0
#                              mostly true                     7755.0  ...         1090.0
#                              no factual content             18345.0  ...         1396.0
#            The Other 98%     mixture of true and false       4749.0  ...          742.0
#                              mostly false                   11571.0  ...          930.0
#                              mostly true                     2896.0  ...          372.0
#                              no factual content             10337.0  ...          638.0
# mainstream ABC News Politics mixture of true and false         76.0  ...           59.0
#                              mostly true                       12.0  ...           28.0
#                              no factual content                38.0  ...           23.0
#            CNN Politics      mixture of true and false        270.0  ...          315.0
#                              mostly true                       48.0  ...          194.0
#                              no factual content                64.0  ...          184.0
#            Politico          mixture of true and false       7325.0  ...         1510.0
#                              mostly true                       33.0  ...           96.0
#                              no factual content                48.0  ...           48.0
# right      Eagle Rising      mixture of true and false        110.0  ...           32.0
#                              mostly false                     534.0  ...           55.0
#                              mostly true                       46.0  ...           17.0
#                              no factual content               250.0  ...           17.0
#            Freedom Daily     mixture of true and false        342.0  ...          140.0
#                              mostly false                    1623.0  ...          276.0
#                              mostly true                      908.0  ...          191.0
#                              no factual content              2025.0  ...          262.0
#            Right Wing News   mixture of true and false        457.0  ...          131.0
#                              mostly false                     790.0  ...          201.0
#                              mostly true                       91.0  ...           50.0
#                              no factual content              4933.0  ...          201.0
#
# [33 rows x 3 columns]

# %% [markdown]
# Averages:

# %%
grp[ENGAGEMENT_COLS].mean().round()
# Out:
#                                                         share_count  \
# Category   Page              Rating
# left       Addicting Info    mixture of true and false         1516
#                              mostly false                      1891
#                              mostly true                       1005
#                              no factual content                2766
#            Occupy Democrats  mixture of true and false        26036
#                              mostly false                     10603
#                              mostly true                      16215
#                              no factual content               55171
#            The Other 98%     mixture of true and false         9544
#                              mostly false                     13738
#                              mostly true                      10765
#                              no factual content               32588
# mainstream ABC News Politics mixture of true and false           76
#                              mostly true                         42
#                              no factual content                  63
#            CNN Politics      mixture of true and false          239
#                              mostly true                        181
#                              no factual content                 215
#            Politico          mixture of true and false         7325
#                              mostly true                        156
#                              no factual content                  83
# right      Eagle Rising      mixture of true and false         1182
#                              mostly false                      1300
#                              mostly true                        263
#                              no factual content                 506
#            Freedom Daily     mixture of true and false         1377
#                              mostly false                      3390
#                              mostly true                       2543
#                              no factual content                2712
#            Right Wing News   mixture of true and false         1472
#                              mostly false                      2432
#                              mostly true                        668
#                              no factual content                7713
#
#                                                         reaction_count  \
# Category   Page              Rating
# left       Addicting Info    mixture of true and false            3451
#                              mostly false                         4004
#                              mostly true                          2800
#                              no factual content                   4520
#            Occupy Democrats  mixture of true and false           28933
#                              mostly false                        22854
#                              mostly true                         25000
#                              no factual content                  54388
#            The Other 98%     mixture of true and false           11270
#                              mostly false                        24557
#                              mostly true                         14053
#                              no factual content                  34363
# mainstream ABC News Politics mixture of true and false             479
#                              mostly true                           176
#                              no factual content                    159
#            CNN Politics      mixture of true and false            1327
#                              mostly true                           672
#                              no factual content                    656
#            Politico          mixture of true and false           20344
#                              mostly true                           832
#                              no factual content                    420
# right      Eagle Rising      mixture of true and false             707
#                              mostly false                          926
#                              mostly true                           300
#                              no factual content                    573
#            Freedom Daily     mixture of true and false            2489
#                              mostly false                         4651
#                              mostly true                          3692
#                              no factual content                   5089
#            Right Wing News   mixture of true and false            2465
#                              mostly false                         3999
#                              mostly true                          1602
#                              no factual content                   9705
#
#                                                         comment_count
# Category   Page              Rating
# left       Addicting Info    mixture of true and false            460
#                              mostly false                         704
#                              mostly true                          368
#                              no factual content                   227
#            Occupy Democrats  mixture of true and false           2924
#                              mostly false                        1426
#                              mostly true                         1624
#                              no factual content                  4959
#            The Other 98%     mixture of true and false            942
#                              mostly false                        1051
#                              mostly true                          793
#                              no factual content                  1092
# mainstream ABC News Politics mixture of true and false             59
#                              mostly true                           67
#                              no factual content                   103
#            CNN Politics      mixture of true and false            262
#                              mostly true                          321
#                              no factual content                   346
#            Politico          mixture of true and false           1510
#                              mostly true                          166
#                              no factual content                    54
# right      Eagle Rising      mixture of true and false            149
#                              mostly false                          89
#                              mostly true                           67
#                              no factual content                    49
#            Freedom Daily     mixture of true and false            553
#                              mostly false                         576
#                              mostly true                          480
#                              no factual content                   390
#            Right Wing News   mixture of true and false            448
#                              mostly false                         434
#                              mostly true                          291
#                              no factual content                   360

# %% [markdown]
# ## Engagement by post type

# %% [markdown]
# Medians:

# %%
type_grp[ENGAGEMENT_COLS].median().round()
# Out:
#                                         share_count  reaction_count  \
# Category   Page              Post Type
# left       Addicting Info    link               563            2195
#                              photo             3532            5814
#                              video              275            1302
#            Occupy Democrats  link              5130           10862
#                              photo            18294           34730
#                              video            26648           30011
#            The Other 98%     link              3391            8836
#                              photo            12441           26990
#                              video             1598            4751
# mainstream ABC News Politics link                 9              68
#                              photo                6              30
#                              text                 2               5
#                              video               37             138
#            CNN Politics      link                36             284
#                              photo               51             118
#                              text                 4              95
#                              video              125             691
#            Politico          link                32             290
#                              photo                8              62
#                              text                 2              58
#                              video               48             428
# right      Eagle Rising      link                70             154
#                              photo              569             750
#                              video               38              73
#            Freedom Daily     link               964            2263
#                              text                 3              47
#            Right Wing News   link               246             824
#                              photo             8474           12115
#
#                                         comment_count
# Category   Page              Post Type
# left       Addicting Info    link                 262
#                              photo                534
#                              video                117
#            Occupy Democrats  link                1020
#                              photo               1290
#                              video               2287
#            The Other 98%     link                 529
#                              photo                604
#                              video                364
# mainstream ABC News Politics link                  27
#                              photo                 14
#                              text                   2
#                              video                 32
#            CNN Politics      link                 177
#                              photo                 88
#                              text                 103
#                              video                456
#            Politico          link                  92
#                              photo                 27
#                              text                  26
#                              video                132
# right      Eagle Rising      link                  20
#                              photo                 24
#                              video                 14
#            Freedom Daily     link                 224
#                              text                   7
#            Right Wing News   link                  87
#                              photo                180

# %% [markdown]
# Averages:

# %%
type_grp[ENGAGEMENT_COLS].mean().round()
# Out:
#                                         share_count  reaction_count  \
# Category   Page              Post Type
# left       Addicting Info    link              1168            3028
#                              photo             6021            7128
#                              video              275            1302
#            Occupy Democrats  link              7463           16094
#                              photo            25268           43735
#                              video            97767           62746
#            The Other 98%     link             10341           13847
#                              photo            28875           38285
#                              video            16712            9021
# mainstream ABC News Politics link                23             124
#                              photo                9              51
#                              text                 2               5
#                              video               90             273
#            CNN Politics      link               176             604
#                              photo               77             212
#                              text                 4              95
#                              video              237            1088
#            Politico          link               181             879
#                              photo               77             299
#                              text                 2              58
#                              video              201            1132
# right      Eagle Rising      link               454             411
#                              photo             1461            1151
#                              video               38              94
#            Freedom Daily     link              2497            3718
#                              text                 3              47
#            Right Wing News   link               999            2048
#                              photo            11664           12928
#
#                                         comment_count
# Category   Page              Post Type
# left       Addicting Info    link                 391
#                              photo                578
#                              video                117
#            Occupy Democrats  link                1272
#                              photo               1604
#                              video               9531
#            The Other 98%     link                 882
#                              photo                924
#                              video                959
# mainstream ABC News Politics link                  40
#                              photo                 21
#                              text                   2
#                              video                125
#            CNN Politics      link                 256
#                              photo                112
#                              text                 103
#                              video                663
#            Politico          link                 168
#                              photo                 31
#                              text                  26
#                              video                203
# right      Eagle Rising      link                  81
#                              photo                 80
#                              video                 31
#            Freedom Daily     link                 521
#                              text                   7
#            Right Wing News   link                 358
#                              photo                408

# %% [markdown]
# ## Shares by factual vs. no factual content

# %%
grp = posts.groupby([ "Category", "Page", posts["Rating"] == "no factual content" ])
pd.DataFrame({
    "median": grp["share_count"].median(),
    "average": grp["share_count"].mean()
}).round()\
    .unstack().stack(level=0).rename(columns={True: "no factual content", False: "factual content"})
# Out:
# Rating                                factual content  no factual content
# Category   Page
# left       Addicting Info    average             1150                2766
#                              median               578                 399
#            Occupy Democrats  average            18155               55171
#                              median              7997               18345
#            The Other 98%     average            10820               32588
#                              median              3484               10337
# mainstream ABC News Politics average               43                  63
#                              median                13                  38
#            CNN Politics      average              182                 215
#                              median                48                  64
#            Politico          average              183                  83
#                              median                33                  48
# right      Eagle Rising      average              656                 506
#                              median                75                 250
#            Freedom Daily     average             2466                2712
#                              median               947                2025
#            Right Wing News   average             1127                7713
#                              median               246                4933

# %% [markdown]
# ## Shares for mostly-true vs. others for partisan pages

# %%
grp = posts.groupby([ "Category", "Page", posts["Rating"] == "mostly true" ])
pd.DataFrame({
    "median": grp["share_count"].median(),
    "average": grp["share_count"].mean()
}).round()\
    .unstack().stack(level=0).rename(columns={True: "mostly true", False: "everything else"})\
    [[ "mostly true", "everything else" ]].loc[["left", "right"]]
# Out:
# Rating                             mostly true  everything else
# Category Page
# left     Addicting Info   average         1005             1894
#                           median           523              882
#          Occupy Democrats average        16215            41812
#                           median          7755            13330
#          The Other 98%    average        10765            26432
#                           median          2896             8236
# right    Eagle Rising     average          263              886
#                           median            46              201
#          Freedom Daily    average         2543             2407
#                           median           908             1142
#          Right Wing News  average          668             2215
#                           median            91              568

# %% [markdown]
# ---
#
# ---
#
# ---
